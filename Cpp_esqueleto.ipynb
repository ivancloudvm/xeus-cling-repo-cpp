// %% [markdown]
// # Esqueleto programa C++

// %%
#include <bits/stdc++.h>
using namespace std;

int main() {
	ios_base::sync_with_stdio(0); cin.tie(0);
	///Literalmente solo imprimimos texto
	cout << "Hola mundo";
	return 0;
}
